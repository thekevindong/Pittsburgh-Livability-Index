# %%
For this Fire Incident Data Set, we shall do a detail examination of what this DataSet offers.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = 'FireIncident.csv'  
df = pd.read_csv(file_path)

df_neighborhood_totals = df.groupby('neighborhood')['alarms'].sum().reset_index()

pd.set_option('display.max_rows', None)  

df_neighborhood_totals
# Out:
#                  neighborhood  alarms
# 0            Allegheny Center      26
# 1              Allegheny West      15
# 2                   Allentown      95
# 3                   Arlington      31
# 4           Arlington Heights      10
# 5                  Banksville      28
# 6           Bedford Dwellings      38
# 7                   Beechview      84
# 8                 Beltzhoover      99
# 9                  Bloomfield     105
# 10                      Bluff      91
# 11                    Bon Air       6
# 12           Brighton Heights     108
# 13                  Brookline     107
# 14       California-Kirkbride      23
# 15                    Carrick     201
# 16  Central Business District     192
# 17      Central Lawrenceville      43
# 18          Central Northside      94
# 19            Central Oakland      70
# 20             Chartiers City       9
# 21                    Chateau      12
# 22            Crafton Heights      60
# 23           Crawford-Roberts      70
# 24           Duquesne Heights      29
# 25             East Allegheny      90
# 26              East Carnegie       9
# 27                 East Hills     105
# 28               East Liberty     132
# 29                    Elliott      37
# 30                     Esplen      14
# 31                  Fairywood      14
# 32                   Fineview      29
# 33                 Friendship      14
# 34                   Garfield      80
# 35                 Glen Hazel      16
# 36                 Greenfield      66
# 37                       Hays       6
# 38                  Hazelwood     125
# 39              Highland Park      39
# 40             Homewood North     127
# 41             Homewood South     128
# 42              Homewood West      31
# 43                  Knoxville     136
# 44                    Larimer      81
# 45              Lincoln Place      25
# 46   Lincoln-Lemington-Belmar     136
# 47        Lower Lawrenceville      36
# 48                 Manchester      51
# 49         Marshall-Shadeland      93
# 50                Middle Hill      77
# 51                Morningside      13
# 52       Mount Oliver Borough       2
# 53           Mount Washington     124
# 54                 Mt. Oliver       7
# 55              New Homestead       4
# 56              North Oakland     105
# 57                North Shore      15
# 58          Northview Heights      43
# 59                    Oakwood       9
# 60                  Overbrook      26
# 61                Perry North      67
# 62                Perry South     121
# 63               Point Breeze      43
# 64         Point Breeze North      37
# 65                Polish Hill      14
# 66              Regent Square       4
# 67                  Ridgemont       1
# 68                  Shadyside     139
# 69                   Sheraden     118
# 70              South Oakland      53
# 71                South Shore       7
# 72           South Side Flats     164
# 73          South Side Slopes      49
# 74              Spring Garden      12
# 75      Spring Hill-City View      66
# 76        Squirrel Hill North     110
# 77        Squirrel Hill South     150
# 78                  St. Clair       4
# 79            Stanton Heights      36
# 80             Strip District      40
# 81                Summer Hill      10
# 82             Swisshelm Park       8
# 83            Terrace Village      54
# 84                  Troy Hill      50
# 85                 Upper Hill      45
# 86        Upper Lawrenceville      34
# 87                   West End       8
# 88               West Oakland      37
# 89                   Westwood      15
# 90                    Windgap      11

# %%
plt.figure(figsize=(25, 25))
df_neighborhood_totals = df_neighborhood_totals.sort_values(by='alarms', ascending=False)
df_neighborhood_totals.set_index('neighborhood')['alarms'].plot(kind='bar')

plt.title('Total Alarms by each  Neighborhood', font="Times New Roman")
plt.xlabel('Total Number of Alarms', color='#B3E5FC', fontsize=15, fontweight='bold')
plt.ylabel('Neighborhoods', color='#B3E5FC', fontsize=15, fontweight='bold')
plt.style.use('dark_background')

plt.grid(color='#353839', linewidth=0.5)


plt.show()

# %%
df_neighborhood_totals = df_neighborhood_totals.sort_values(by='alarms', ascending=True)

plt.figure(figsize=(10, 20))
plt.barh(df_neighborhood_totals['neighborhood'], df_neighborhood_totals['alarms'])
plt.title('Total Alarms by Neighborhood', color ='#BF00FF')
plt.xlabel('Total Number of Alarms', color='#B3E5FC')
plt.ylabel('Neighborhoods', color='#B3E5FC')


plt.grid(color='#353839', linewidth=0.5)


plt.show()

# %%
plt.figure(figsize=(15, 15))
df_neighborhood_totals.set_index('neighborhood')['alarms'].plot(kind='pie')
plt.style.use('dark_background')
plt.tight_layout() ## Makes Sure that all the Names of the Neighborhoods arent super cut off
plt.show()

# %%
lowest_alarms = df_neighborhood_totals[df_neighborhood_totals['alarms'] == df_neighborhood_totals['alarms'].min()]
lowest_alarms.tail(5)
# Out:
#    neighborhood  alarms
# 67    Ridgemont       1
